# %%
import time
import sys
import json
import datetime
import re

# %%
# import pymongo
# from pymongo import MongoClient

# %%
import requests
from bs4 import BeautifulSoup

# %%
import pandas as pd
import numpy as np

# %%
from datetime import datetime

# %% [markdown]
# # top 25 database

# %%
def api_metadata_docs(api):
#    api = 'https://api.nytimes.com/svc/archive/v1/{year}/{month}.json?api-key=kwQUDL7cdaIuu03LazP2b3F2R0uY1kET'
    api_request = requests.get(api, params={'q': 'requests+language:python'})
    print(api_request.status_code)
    json = api_request.json()
    json_response = json['response']
    json_docs = json_response['docs']
    return json_docs

# %%
url = 'https://www.cigaraficionado.com/top25cigar/e-p-carrillo-pledge-prequel-2020'

# %%
page = requests.get(url)
soup = BeautifulSoup(page.content, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="en-US">
#  <head>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#     window.dataLayer.push({
#       'channel': 'Top 25'
#     });
#   </script>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="M. Shanken Communications, Inc." name="author"/>
#   <meta content="#6b3f25" name="msapplication-TileColor"/>
#   <meta content="https://mshanken.imgix.net/cao/mstile-144x144.png" name="msapplication-TileImage"/>
#   <meta content="https://mshanken.imgix.net/cao/browserconfig.xml" name="msapplication-config"/>
#   <meta content="#5D4537" name="theme-color"/>
#   <meta content="" property="og:url"/>
#   <meta content="E.P. Carrillo Pledge Prequel | Cigar Aficionado" property="og:title"/>
# ...

# %%
#name

# %%
#data 
for div in soup.find_all('div', class_ ='top25-detail-attributes'):
    print(div.text)

# %%
#column names
for div in soup.find_all('p'):
    print(div.text)
# Out:
# Don’t Miss WhiskyFest in Hollywood, FL, Chicago and NYC! Use Promo Code WF100 to Buy Tickets!
# It seems the page you're looking for has gone up in smoke.

# %% [markdown]
# # cigaraficionado ratings 1000:

# %%
url = 'https://www.cigaraficionado.com/ratings/1000'
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}

# %%
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')

# %%
type(response.content)
# Out:
# bytes

# %%
respone
# Out:
# <Response [200]>

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" lang="en-US">
# <head>
# <script>
#       window.dataLayer = window.dataLayer || [];
#       window.dataLayer.push({
#         'taxonomy' : 'Error Page'
#       });
# 	</script>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="M. Shanken Communications, Inc." name="author"/>
# <meta content="#6b3f25" name="msapplication-TileColor"/>
# <meta content="https://mshanken.imgix.net/cao/mstile-144x144.png" name="msapplication-TileImage"/>
# <meta content="https://mshanken.imgix.net/cao/browserconfig.xml" name="msapplication-config"/>
# <meta content="#5D4537" name="theme-color"/>
# <meta content="" property="og:url"/>
# <meta content="Cigar Aficionado" property="og:title"/>
# ...

# %%
cigar_series = []

# %%
#cigar image location
image = soup.find('div', class_='col-3 col-md-2 cigar-detail_image')
image = image.find('img')
image = image['src']
image
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 3
#       1 #cigar image location
#       2 image = soup.find('div', class_='col-3 col-md-2 cigar-detail_image')
# ----> 3 image = image.find('img')
#       4 image = image['src']
#       5 image
#
# AttributeError: 'NoneType' object has no attribute 'find'

# %%
#cigar name
title = soup.find('div', class_='col-9 col-md-10 ml-auto order-1 cigar-detail_title')
title = title.h1.text
title

# %%
#cigar score
score = soup.find('div', class_='attributes-item_score')
score = score.text
score

# %%
#cigar length
length = soup.find('div', class_='col-6 col-md-3 col-lg-3 attributes-item pr-lg-24 pr-xl-49')
length = length.find('div', class_='attributes-item_label').strong.text
length

# %%
#cigar gauge
gauge = soup.find('div', id='attributeRingGauge')
gauge = gauge.strong.text
gauge

# %%
#cigar stregnth
strength = soup.find('div', class_="attributes-item_lengthpointer-sm")
strenth_string = strength['style']
(strenth_string)
#strength.get('attributes-item_label')

# %%
#cigar tasting notes
tasting_notes = soup.find('div', class_='col-md-10 ml-auto order-3 order-md-2 cigar-detail_tastingnote')
tasting_notes = tasting_notes.p
tasting_notes = tasting_notes.text
tasting_notes

# %%
#cigar details
#Size, Filler, Binder, Wrapper ,Country ,Price, Issue
details = soup.find_all('p', attrs={'class':'mb-0'})
for detail in details:
    if 'Size:' in detail.strong:
        size = detail.text
    if 'Filler:' in detail.strong:
        filler = detail.text
    if 'Binder:' in detail.strong:
        binder = detail.text
    if 'Wrapper:' in detail.strong:
        wrapper = detail.text
    if 'Country:' in detail.strong:
        country = detail.text
    if 'Price:' in detail.strong:
        price = detail.text
    if 'Issue:' in detail.strong:
        issue = detail.text
issue, price, country, wrapper, filler, size

# %%
#more reviews of same cigar
additional = soup.find_all('div', class_='col-12 col-md-6 col-lg-12 cigar-detail_additional')
more_reviews = []
for add in additional:
    score = add.find('div',class_='attributes-item_score').text.strip(' \n')
    date = add.find('div', class_='col').text.strip(' \n')
    date = date.split('\n')
    review = (score, date)
    more_reviews.append(review)
more_reviews

# %% [markdown]
# # put in headers

# %%
# bank = []
# for href in list(range(1000,1005)):
#     url = f'https://www.cigaraficionado.com/ratings/{href}'
#     response = requests.get(url,timeout=(5,20), headers=headers)
    
#     print(response.status_code)
#     print(datetime.now())
    
#     if response.status_code == 403:
#         print(url)
#         print(response.raise_for_status())
        
#     soup = BeautifulSoup(response.content, 'html.parser')
#     bank.append(soup)
#     time.sleep(10)
# print(len(bank))

# %%
type(bank[0])

# %%
def cigar_aficionado_scrape(soup):
    d = {}
    
    #cigar image location
    image = soup.find('div', class_='col-3 col-md-2 cigar-detail_image')
    image = image.find('img')
    image = image['src']
    d['image'] = image
    
    #cigar name
    name = soup.find('div', class_='col-9 col-md-10 ml-auto order-1 cigar-detail_title')
    name = name.h1.text
    d['name'] = name
    
    #cigar score
    score = soup.find('div', class_='attributes-item_score')
    score = score.text
    d['score'] = score
    
    #cigar length
    length = soup.find('div', class_='col-6 col-md-3 col-lg-3 attributes-item pr-lg-24 pr-xl-49')
    length = length.find('div', class_='attributes-item_label').strong.text
    d['length'] = length
    
    #cigar gauge
    gauge = soup.find('div', id='attributeRingGauge')
    gauge = gauge.strong.text
    d['gauge'] = gauge
    
    #cigar stregnth
    strength = soup.find('div', class_="attributes-item_lengthpointer-sm")
    strenth_string = strength['style']
    d['strenth_string'] = strenth_string
    #strength.get('attributes-item_label')
    
    #cigar tasting notes
    tasting_notes = soup.find('div', class_='col-md-10 ml-auto order-3 order-md-2 cigar-detail_tastingnote')
    tasting_notes = tasting_notes.p
    tasting_notes = tasting_notes.text
    d['tasting_notes'] = tasting_notes
    
    #cigar details
    #Size, Filler, Binder, Wrapper ,Country ,Price, Issue
    details = soup.find_all('p', attrs={'class':'mb-0'})
    for detail in details:
        if 'Size:' in detail.strong:
            size = detail.text
            d['size'] = size
            
        if 'Filler:' in detail.strong:
            filler = detail.text
            d['filler'] = filler
            
        if 'Binder:' in detail.strong:
            binder = detail.text
            d['binder'] = binder
            
        if 'Wrapper:' in detail.strong:
            wrapper = detail.text
            d['wrapper'] = wrapper 
            
        if 'Country:' in detail.strong:
            country = detail.text
            d['country'] = country 
            
        if 'Price:' in detail.strong:
            price = detail.text
            d['price'] = price
            
        if 'Issue:' in detail.strong:
            issue = detail.text
            d['issue'] = issue
    
    #more reviews of same cigar
    additional = soup.find_all('div', class_='col-12 col-md-6 col-lg-12 cigar-detail_additional')
    more_reviews = []
    for add in additional:
        score = add.find('div',class_='attributes-item_score').text.strip(' \n')
        date = add.find('div', class_='col').text.strip(' \n')
        date = date.split('\n')
        review = (score, date)
        more_reviews.append(review)
    d['more_reviews'] = more_reviews
    
    return d

# %% [markdown]
# # scrape to mongodb

# %%
# Define MongoDb database and Collection
mongo_client = pymongo.MongoClient('localhost', 27017)
cigars = mongo_client['cigars']
cigar_aficionado = cigars['cigar_aficionado']

# %%
type(cigar_aficionado)

# %%
# def scrape_html_mongodv(href_start, href_stop):
    for href in list(range(href_start, href_stop)):
        d = {}
        
        url = f'https://www.cigaraficionado.com/ratings/{href}'
        headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
        print(datetime.now())
        response = requests.get(url,timeout=(5,20), headers=headers)
        print(response.status_code)
        
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')
            d[str(href)] = cigar_aficionado_scrape(soup)
            print(url)
            
        elif response.status_code == 403:
            d[str(href)] = url
            error_403 += 1
            print(url)
            
        elif response.status_code == 404:
            d[str(href)] = None
            
        print(href)    
        cigars.cigar_aficionado.insert_one(d)
        time.sleep(2)

# %%
# data_list = list(cigar_aficionado.find())

# %%
test = data_list[:10]

# %%
isinstance(ele,dict)

# %%
new_list = []
for dic in data_list:
    for key, val in dic.items():
        if isinstance(val, dict):
            val['href'] = key
            new_list.append(val)

# %%
data = pd.DataFrame(new_list)

# %%
# data.to_csv('cigar_aficionado.csv')

# %% [markdown]
# # fuction url-df

# %%
url = requests.get('https://www.cigaraficionado.com/ratings/1004')
url.status_code

# %%
soup = BeautifulSoup(url, 'html.parser')

# %%
soup

# %%
reviews = list(range(1000, 1050))

# %%
df = pd.DataFrame()

for num in reviews:
    link = f'https://www.cigaraficionado.com/ratings/{num}'
    print(link)
    cigar = cigar_aficionado_scrape(link)
    df.append(cigar, ignore_index=True)
df.shape

# %%
url = requests.get('https://www.cigaraficionado.com/ratings/1000')
soup = BeautifulSoup(url.content, 'html.parser')
scrape = soup.find('div', class_="row cigar-detail").text

# %%
scrape

# %%
for _, i in enumerate(scrape):
    print(f'{i} --- {_}')

# %%
scrape = cigardf

# %%
cigardf

# %%
cigardf = cigardf[cigardf != '']
cigardf = cigardf.str.strip()

# %%
#cigardf = cigardf[cigardf.value_counts() > 4]

# %%
cigardf.shape

# %%
cigardf = cigardf.dropna(axis=1)

# %%
cigardf.shape

# %%
cigardf

# %%
for (number) in reviews:
    print(f'https://www.cigaraficionado.com/ratings/{number}')
